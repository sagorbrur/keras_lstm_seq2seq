# %%
from __future__ import print_function

from keras.models import Model
from keras.layers import Input, LSTM, Dense
import numpy as np
# Out:
# Using TensorFlow backend.

# %%
batch_size = 64  # Batch size for training.
epochs = 100  # Number of epochs to train for.
latent_dim = 256  # Latent dimensionality of the encoding space.
num_samples = 10000  # Number of samples to train on.
# Path to the data txt file on disk.
data_path = 'data/en_bn.txt'

# Vectorize the data.
input_texts = []
target_texts = []
input_characters = set()
target_characters = set()

# %%
with open(data_path, 'r', encoding='utf-8') as f:
    lines = f.read().split('\n')
for line in lines[: min(num_samples, len(lines) - 1)]:
    input_text, target_text = line.split('\t')
    # We use "tab" as the "start sequence" character
    # for the targets, and "\n" as "end sequence" character.
    target_text = '\t' + target_text + '\n'
    input_texts.append(input_text)
    target_texts.append(target_text)
    for char in input_text:
        if char not in input_characters:
            input_characters.add(char)
    for char in target_text:
        if char not in target_characters:
            target_characters.add(char)

input_characters = sorted(list(input_characters))
target_characters = sorted(list(target_characters))
num_encoder_tokens = len(input_characters)
num_decoder_tokens = len(target_characters)
max_encoder_seq_length = max([len(txt) for txt in input_texts])
max_decoder_seq_length = max([len(txt) for txt in target_texts])

print('Number of samples:', len(input_texts))
print('Number of unique input tokens:', num_encoder_tokens)
print('Number of unique output tokens:', num_decoder_tokens)
print('Max sequence length for inputs:', max_encoder_seq_length)
print('Max sequence length for outputs:', max_decoder_seq_length)
# Out:
# Number of samples: 523
# Number of unique input tokens: 56
# Number of unique output tokens: 61
# Max sequence length for inputs: 10
# Max sequence length for outputs: 26

# %%
input_token_index = dict(
    [(char, i) for i, char in enumerate(input_characters)])
target_token_index = dict(
    [(char, i) for i, char in enumerate(target_characters)])

encoder_input_data = np.zeros(
    (len(input_texts), max_encoder_seq_length, num_encoder_tokens),
    dtype='float32')
decoder_input_data = np.zeros(
    (len(input_texts), max_decoder_seq_length, num_decoder_tokens),
    dtype='float32')
decoder_target_data = np.zeros(
    (len(input_texts), max_decoder_seq_length, num_decoder_tokens),
    dtype='float32')

for i, (input_text, target_text) in enumerate(zip(input_texts, target_texts)):
    for t, char in enumerate(input_text):
        encoder_input_data[i, t, input_token_index[char]] = 1.
    for t, char in enumerate(target_text):
        # decoder_target_data is ahead of decoder_input_data by one timestep
        decoder_input_data[i, t, target_token_index[char]] = 1.
        if t > 0:
            # decoder_target_data will be ahead by one timestep
            # and will not include the start character.
            decoder_target_data[i, t - 1, target_token_index[char]] = 1.

# %%
# Define an input sequence and process it.
encoder_inputs = Input(shape=(None, num_encoder_tokens))
encoder = LSTM(latent_dim, return_state=True)
encoder_outputs, state_h, state_c = encoder(encoder_inputs)
# We discard `encoder_outputs` and only keep the states.
encoder_states = [state_h, state_c]

# Set up the decoder, using `encoder_states` as initial state.
decoder_inputs = Input(shape=(None, num_decoder_tokens))
# We set up our decoder to return full output sequences,
# and to return internal states as well. We don't use the
# return states in the training model, but we will use them in inference.
decoder_lstm = LSTM(latent_dim, return_sequences=True, return_state=True)
decoder_outputs, _, _ = decoder_lstm(decoder_inputs,
                                     initial_state=encoder_states)
decoder_dense = Dense(num_decoder_tokens, activation='softmax')
decoder_outputs = decoder_dense(decoder_outputs)

# Define the model that will turn
# `encoder_input_data` & `decoder_input_data` into `decoder_target_data`
model = Model([encoder_inputs, decoder_inputs], decoder_outputs)

# Run training
model.compile(optimizer='rmsprop', loss='categorical_crossentropy')
model.fit([encoder_input_data, decoder_input_data], decoder_target_data,
          batch_size=batch_size,
          epochs=epochs,
          validation_split=0.2)
# Save model
model.save('logs/testbn.h5')
# Out:
# Train on 418 samples, validate on 105 samples
# Epoch 1/100
# 418/418 [==============================] - 2s 4ms/step - loss: 1.7566 - val_loss: 1.6527
# Epoch 2/100
# 418/418 [==============================] - 1s 2ms/step - loss: 1.4854 - val_loss: 1.6056
# Epoch 3/100
# 418/418 [==============================] - 1s 2ms/step - loss: 1.4301 - val_loss: 1.5792
# Epoch 4/100
# 418/418 [==============================] - 1s 2ms/step - loss: 1.3984 - val_loss: 1.5880
# Epoch 5/100
# 418/418 [==============================] - 1s 2ms/step - loss: 1.3716 - val_loss: 1.5441
# Epoch 6/100
# 418/418 [==============================] - 1s 2ms/step - loss: 1.3509 - val_loss: 1.5457
# Epoch 7/100
# 418/418 [==============================] - 1s 2ms/step - loss: 1.3374 - val_loss: 1.5232
# Epoch 8/100
# 418/418 [==============================] - 1s 2ms/step - loss: 1.3019 - val_loss: 1.5426
# Epoch 9/100
# 418/418 [==============================] - 1s 2ms/step - loss: 1.2917 - val_loss: 1.5103
# Epoch 10/100
# 418/418 [==============================] - 1s 2ms/step - loss: 1.2758 - val_loss: 1.4984
# Epoch 11/100
# 418/418 [==============================] - 1s 2ms/step - loss: 1.2469 - val_loss: 1.5046
# Epoch 12/100
# 418/418 [==============================] - 1s 2ms/step - loss: 1.2307 - val_loss: 1.5078
# Epoch 13/100
# 418/418 [==============================] - 1s 2ms/step - loss: 1.2133 - val_loss: 1.4627
# Epoch 14/100
# 418/418 [==============================] - 1s 2ms/step - loss: 1.1859 - val_loss: 1.4906
# Epoch 15/100
# 418/418 [==============================] - 1s 2ms/step - loss: 1.1688 - val_loss: 1.4761
# Epoch 16/100
# 418/418 [==============================] - 1s 2ms/step - loss: 1.1576 - val_loss: 1.4186
# Epoch 17/100
# 418/418 [==============================] - 1s 2ms/step - loss: 1.1056 - val_loss: 1.4486
# Epoch 18/100
# 418/418 [==============================] - 1s 2ms/step - loss: 1.1104 - val_loss: 1.4472
# Epoch 19/100
# 418/418 [==============================] - 1s 2ms/step - loss: 1.0671 - val_loss: 1.3745
# Epoch 20/100
# 418/418 [==============================] - 1s 2ms/step - loss: 1.0432 - val_loss: 1.3648
# Epoch 21/100
# 418/418 [==============================] - 1s 2ms/step - loss: 1.0261 - val_loss: 1.3645
# Epoch 22/100
# 418/418 [==============================] - 1s 2ms/step - loss: 1.0133 - val_loss: 1.3115
# Epoch 23/100
# 418/418 [==============================] - 1s 2ms/step - loss: 0.9680 - val_loss: 1.3416
# Epoch 24/100
# 418/418 [==============================] - 1s 2ms/step - loss: 0.9450 - val_loss: 1.2918
# Epoch 25/100
# 418/418 [==============================] - 1s 2ms/step - loss: 0.9276 - val_loss: 1.3363
# Epoch 26/100
# 418/418 [==============================] - 1s 2ms/step - loss: 0.9034 - val_loss: 1.3117
# Epoch 27/100
# 418/418 [==============================] - 1s 2ms/step - loss: 0.8851 - val_loss: 1.2407
# Epoch 28/100
# 418/418 [==============================] - 1s 2ms/step - loss: 0.8660 - val_loss: 1.2957
# Epoch 29/100
# 418/418 [==============================] - 1s 2ms/step - loss: 0.8407 - val_loss: 1.2476
# Epoch 30/100
# 418/418 [==============================] - 1s 2ms/step - loss: 0.8223 - val_loss: 1.2485
# Epoch 31/100
# 418/418 [==============================] - 1s 2ms/step - loss: 0.7988 - val_loss: 1.2870
# Epoch 32/100
# 418/418 [==============================] - 1s 2ms/step - loss: 0.7919 - val_loss: 1.2421
# Epoch 33/100
# 418/418 [==============================] - 1s 2ms/step - loss: 0.7634 - val_loss: 1.2514
# Epoch 34/100
# 418/418 [==============================] - 1s 2ms/step - loss: 0.7354 - val_loss: 1.2275
# Epoch 35/100
# 418/418 [==============================] - 1s 2ms/step - loss: 0.7319 - val_loss: 1.2276
# Epoch 36/100
# 418/418 [==============================] - 1s 2ms/step - loss: 0.7111 - val_loss: 1.2145
# Epoch 37/100
# 418/418 [==============================] - 1s 2ms/step - loss: 0.6867 - val_loss: 1.2401
# Epoch 38/100
# 418/418 [==============================] - 1s 2ms/step - loss: 0.6752 - val_loss: 1.2337
# Epoch 39/100
# 418/418 [==============================] - 1s 2ms/step - loss: 0.6478 - val_loss: 1.2170
# Epoch 40/100
# 418/418 [==============================] - 1s 2ms/step - loss: 0.6252 - val_loss: 1.2557
# Epoch 41/100
# 418/418 [==============================] - 1s 2ms/step - loss: 0.6186 - val_loss: 1.2276
# Epoch 42/100
# 418/418 [==============================] - 1s 2ms/step - loss: 0.6031 - val_loss: 1.2282
# Epoch 43/100
# 418/418 [==============================] - 1s 2ms/step - loss: 0.5754 - val_loss: 1.2437
# Epoch 44/100
# 418/418 [==============================] - 1s 2ms/step - loss: 0.5621 - val_loss: 1.2575
# Epoch 45/100
# 418/418 [==============================] - 1s 2ms/step - loss: 0.5370 - val_loss: 1.2843
# Epoch 46/100
# 418/418 [==============================] - 1s 2ms/step - loss: 0.5332 - val_loss: 1.2748
# Epoch 47/100
# 418/418 [==============================] - 1s 2ms/step - loss: 0.4971 - val_loss: 1.2836
# Epoch 48/100
# 418/418 [==============================] - 1s 2ms/step - loss: 0.5006 - val_loss: 1.2999
# Epoch 49/100
# 418/418 [==============================] - 1s 2ms/step - loss: 0.4712 - val_loss: 1.3182
# Epoch 50/100
# 418/418 [==============================] - 1s 2ms/step - loss: 0.4728 - val_loss: 1.3180
# Epoch 51/100
# 418/418 [==============================] - 1s 2ms/step - loss: 0.4374 - val_loss: 1.3109
# Epoch 52/100
# 418/418 [==============================] - 1s 2ms/step - loss: 0.4303 - val_loss: 1.3605
# Epoch 53/100
# 418/418 [==============================] - 1s 2ms/step - loss: 0.4122 - val_loss: 1.3767
# Epoch 54/100
# 418/418 [==============================] - 1s 2ms/step - loss: 0.3978 - val_loss: 1.3609
# Epoch 55/100
# 418/418 [==============================] - 1s 2ms/step - loss: 0.4015 - val_loss: 1.4006
# Epoch 56/100
# 418/418 [==============================] - 1s 2ms/step - loss: 0.3751 - val_loss: 1.3626
# Epoch 57/100
# 418/418 [==============================] - 1s 2ms/step - loss: 0.3563 - val_loss: 1.3992
# Epoch 58/100
# 418/418 [==============================] - 1s 2ms/step - loss: 0.3487 - val_loss: 1.4035
# Epoch 59/100
# 418/418 [==============================] - 1s 2ms/step - loss: 0.3314 - val_loss: 1.4889
# Epoch 60/100
# 418/418 [==============================] - 1s 2ms/step - loss: 0.3370 - val_loss: 1.4090
# Epoch 61/100
# 418/418 [==============================] - 1s 2ms/step - loss: 0.3181 - val_loss: 1.4100
# Epoch 62/100
# 418/418 [==============================] - 1s 2ms/step - loss: 0.2960 - val_loss: 1.4671
# Epoch 63/100
# 418/418 [==============================] - 1s 2ms/step - loss: 0.2807 - val_loss: 1.5010
# Epoch 64/100
# 418/418 [==============================] - 1s 2ms/step - loss: 0.2779 - val_loss: 1.4507
# Epoch 65/100
# 418/418 [==============================] - 1s 2ms/step - loss: 0.2849 - val_loss: 1.4477
# Epoch 66/100
# 418/418 [==============================] - 1s 2ms/step - loss: 0.2549 - val_loss: 1.4930
# Epoch 67/100
# 418/418 [==============================] - 1s 2ms/step - loss: 0.2502 - val_loss: 1.6332
# Epoch 68/100
# 418/418 [==============================] - 1s 2ms/step - loss: 0.2589 - val_loss: 1.5341
# Epoch 69/100
# 418/418 [==============================] - 1s 2ms/step - loss: 0.2286 - val_loss: 1.5248
# Epoch 70/100
# 418/418 [==============================] - 1s 2ms/step - loss: 0.2149 - val_loss: 1.5720
# Epoch 71/100
# 418/418 [==============================] - 1s 2ms/step - loss: 0.2149 - val_loss: 1.5333
# Epoch 72/100
# 418/418 [==============================] - 1s 2ms/step - loss: 0.1999 - val_loss: 1.5791
# Epoch 73/100
# 418/418 [==============================] - 1s 2ms/step - loss: 0.2014 - val_loss: 1.5712
# Epoch 74/100
# 418/418 [==============================] - 1s 2ms/step - loss: 0.1895 - val_loss: 1.5676
# Epoch 75/100
# 418/418 [==============================] - 1s 2ms/step - loss: 0.1883 - val_loss: 1.5404
# Epoch 76/100
# 418/418 [==============================] - 1s 2ms/step - loss: 0.1736 - val_loss: 1.5960
# Epoch 77/100
# 418/418 [==============================] - 1s 2ms/step - loss: 0.1748 - val_loss: 1.5756
# Epoch 78/100
# 418/418 [==============================] - 1s 2ms/step - loss: 0.1549 - val_loss: 1.5939
# Epoch 79/100
# 418/418 [==============================] - 1s 2ms/step - loss: 0.1688 - val_loss: 1.6547
# Epoch 80/100
# 418/418 [==============================] - 1s 2ms/step - loss: 0.1491 - val_loss: 1.6578
# Epoch 81/100
# 418/418 [==============================] - 1s 2ms/step - loss: 0.1464 - val_loss: 1.6594
# Epoch 82/100
# 418/418 [==============================] - 1s 2ms/step - loss: 0.1271 - val_loss: 1.7018
# Epoch 83/100
# 418/418 [==============================] - 1s 2ms/step - loss: 0.1462 - val_loss: 1.6566
# Epoch 84/100
# 418/418 [==============================] - 1s 2ms/step - loss: 0.1364 - val_loss: 1.6913
# Epoch 85/100
# 418/418 [==============================] - 1s 2ms/step - loss: 0.1194 - val_loss: 1.7109
# Epoch 86/100
# 418/418 [==============================] - 1s 2ms/step - loss: 0.1165 - val_loss: 1.6836
# Epoch 87/100
# 418/418 [==============================] - 1s 2ms/step - loss: 0.1258 - val_loss: 1.8413
# Epoch 88/100
# 418/418 [==============================] - 1s 2ms/step - loss: 0.1052 - val_loss: 1.7469
# Epoch 89/100
# 418/418 [==============================] - 1s 2ms/step - loss: 0.1162 - val_loss: 1.7377
# Epoch 90/100
# 418/418 [==============================] - 1s 2ms/step - loss: 0.0948 - val_loss: 1.7622
# Epoch 91/100
# 418/418 [==============================] - 1s 2ms/step - loss: 0.1082 - val_loss: 1.9700
# Epoch 92/100
# 418/418 [==============================] - 1s 2ms/step - loss: 0.0993 - val_loss: 1.7508
# Epoch 93/100
# 418/418 [==============================] - 1s 2ms/step - loss: 0.0922 - val_loss: 1.7874
# Epoch 94/100
# 418/418 [==============================] - 1s 2ms/step - loss: 0.0854 - val_loss: 1.8078
# Epoch 95/100
# 418/418 [==============================] - 1s 2ms/step - loss: 0.0836 - val_loss: 1.7724
# Epoch 96/100
# 418/418 [==============================] - 1s 2ms/step - loss: 0.0937 - val_loss: 1.8499
# Epoch 97/100
# 418/418 [==============================] - 1s 2ms/step - loss: 0.0774 - val_loss: 1.8299
# Epoch 98/100
# 418/418 [==============================] - 1s 2ms/step - loss: 0.0746 - val_loss: 1.8551
# Epoch 99/100
# 418/418 [==============================] - 1s 2ms/step - loss: 0.0755 - val_loss: 1.8457
# Epoch 100/100
# 418/418 [==============================] - 1s 2ms/step - loss: 0.0745 - val_loss: 1.9163
# /home/semanticslab13/anaconda3/envs/tf3/lib/python3.6/site-packages/keras/engine/network.py:877: UserWarning: Layer lstm_2 was passed non-serializable keyword arguments: {'initial_state': [<tf.Tensor 'lstm_1/while/Exit_2:0' shape=(?, 256) dtype=float32>, <tf.Tensor 'lstm_1/while/Exit_3:0' shape=(?, 256) dtype=float32>]}. They will not be included in the serialized model (and thus will be missing at deserialization time).
#   '. They will not be included '

# %%
# Define sampling models
encoder_model = Model(encoder_inputs, encoder_states)

decoder_state_input_h = Input(shape=(latent_dim,))
decoder_state_input_c = Input(shape=(latent_dim,))
decoder_states_inputs = [decoder_state_input_h, decoder_state_input_c]
decoder_outputs, state_h, state_c = decoder_lstm(
    decoder_inputs, initial_state=decoder_states_inputs)
decoder_states = [state_h, state_c]
decoder_outputs = decoder_dense(decoder_outputs)
decoder_model = Model(
    [decoder_inputs] + decoder_states_inputs,
    [decoder_outputs] + decoder_states)

# Reverse-lookup token index to decode sequences back to
# something readable.
reverse_input_char_index = dict(
    (i, char) for char, i in input_token_index.items())
reverse_target_char_index = dict(
    (i, char) for char, i in target_token_index.items())

# %%
def decode_sequence(input_seq):
    # Encode the input as state vectors.
    states_value = encoder_model.predict(input_seq)

    # Generate empty target sequence of length 1.
    target_seq = np.zeros((1, 1, num_decoder_tokens))
    # Populate the first character of target sequence with the start character.
    target_seq[0, 0, target_token_index['\t']] = 1.

    # Sampling loop for a batch of sequences
    # (to simplify, here we assume a batch of size 1).
    stop_condition = False
    decoded_sentence = ''
    while not stop_condition:
        output_tokens, h, c = decoder_model.predict(
            [target_seq] + states_value)

        # Sample a token
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_char = reverse_target_char_index[sampled_token_index]
        decoded_sentence += sampled_char

        # Exit condition: either hit max length
        # or find stop character.
        if (sampled_char == '\n' or
           len(decoded_sentence) > max_decoder_seq_length):
            stop_condition = True

        # Update the target sequence (of length 1).
        target_seq = np.zeros((1, 1, num_decoder_tokens))
        target_seq[0, 0, sampled_token_index] = 1.

        # Update states
        states_value = [h, c]

    return decoded_sentence

# %%
# #Testing with a single line

# input_sentence = "How are you?"
# test_sentence_tokenized = np.zeros(
#   (1, max_encoder_seq_length, num_encoder_tokens), dtype='float32')
# for t, char in enumerate(input_sentence):
#   test_sentence_tokenized[0, t, input_token_index[char]] = 1.
# print(input_sentence)
# print(decode_sequence(test_sentence_tokenized))

# %%
for seq_index in range(100):
    # Take one sequence (part of the training set)
    # for trying out decoding.
    input_seq = encoder_input_data[seq_index: seq_index + 1]
    decoded_sentence = decode_sequence(input_seq)
    print('-')
    print('Input sentence:', input_texts[seq_index])
    print('Decoded sentence:', decoded_sentence)
# Out:
# -
# Input sentence: Go.
# Decoded sentence: যান।
#
# -
# Input sentence: Hi.
# Decoded sentence: হাই।
#
# -
# Input sentence: Run!
# Decoded sentence: চালান!
#
# -
# Input sentence: Run!
# Decoded sentence: চালান!
#
# -
# Input sentence: Wow!
# Decoded sentence: কি দারুন!
#
# -
# Input sentence: Fire!
# Decoded sentence: ফায়ার!
#
# -
# Input sentence: Help!
# Decoded sentence: সাহায্য করুন!
#
# -
# Input sentence: Jump.
# Decoded sentence: আমা দেরেছি।
#
# -
# Input sentence: Stop!
# Decoded sentence: বন্ধ করুন!
#
# -
# Input sentence: Stop!
# Decoded sentence: বন্ধ করুন!
#
# -
# Input sentence: Stop!
# Decoded sentence: বন্ধ করুন!
#
# -
# Input sentence: Wait!
# Decoded sentence: অপেক্ষা কর
#
# -
# Input sentence: Wait!
# Decoded sentence: অপেক্ষা কর
#
# -
# Input sentence: Go on.
# Decoded sentence: যান।
#
# -
# Input sentence: Go on.
# Decoded sentence: যান।
#
# -
# Input sentence: Go on.
# Decoded sentence: যান।
#
# -
# Input sentence: Hello!
# Decoded sentence: হ্যালো!
#
# -
# Input sentence: Hello!
# Decoded sentence: হ্যালো!
#
# -
# Input sentence: I see.
# Decoded sentence: আমি এটি ব্যবহার করি.
#
# -
# Input sentence: I try.
# Decoded sentence: আমি চেষ্টা করেছিলাম.
#
# -
# Input sentence: I won!
# Decoded sentence: আমি জিতেছে।
#
# -
# Input sentence: I won!
# Decoded sentence: আমি জিতেছে।
#
# -
# Input sentence: Oh no!
# Decoded sentence: ওহ না!
#
# -
# Input sentence: Attack!
# Decoded sentence: হামলা!
#
# -
# Input sentence: Attack!
# Decoded sentence: হামলা!
#
# -
# Input sentence: Cheers!
# Decoded sentence: চিয়ার্স!
#
# -
# Input sentence: Cheers!
# Decoded sentence: চিয়ার্স!
#
# -
# Input sentence: Cheers!
# Decoded sentence: চিয়ার্স!
#
# -
# Input sentence: Cheers!
# Decoded sentence: চিয়ার্স!
#
# -
# Input sentence: Get up.
# Decoded sentence: উঠে পড়.
#
# -
# Input sentence: Go now.
# Decoded sentence: এখন যাও.
#
# -
# Input sentence: Go now.
# Decoded sentence: এখন যাও.
#
# -
# Input sentence: Go now.
# Decoded sentence: এখন যাও.
#
# -
# Input sentence: Got it!
# Decoded sentence: বুঝেছি!
#
# -
# Input sentence: Got it!
# Decoded sentence: বুঝেছি!
#
# -
# Input sentence: Got it?
# Decoded sentence: বুঝেছি?
#
# -
# Input sentence: Got it?
# Decoded sentence: বুঝেছি?
#
# -
# Input sentence: Got it?
# Decoded sentence: বুঝেছি?
#
# -
# Input sentence: Hop in.
# Decoded sentence: হপ ইন।
#
# -
# Input sentence: Hop in.
# Decoded sentence: হপ ইন।
#
# -
# Input sentence: Hug me.
# Decoded sentence: আমাকে ছেড়ে দাও।
#
# -
# Input sentence: Hug me.
# Decoded sentence: আমাকে ছেড়ে দাও।
#
# -
# Input sentence: I fell.
# Decoded sentence: আমি প্রস্থান করেছি.
#
# -
# Input sentence: I fell.
# Decoded sentence: আমি প্রস্থান করেছি.
#
# -
# Input sentence: I know.
# Decoded sentence: আমি জান.
#
# -
# Input sentence: I left.
# Decoded sentence: আমি প্রস্থান করেছি.
#
# -
# Input sentence: I left.
# Decoded sentence: আমি প্রস্থান করেছি.
#
# -
# Input sentence: I lost.
# Decoded sentence: আমি প্রস্থান করেছি.
#
# -
# Input sentence: I'm 19.
# Decoded sentence: আমি ঠিক আছি.
#
# -
# Input sentence: I'm OK.
# Decoded sentence: আমি ঠিক আছি.
#
# -
# Input sentence: I'm OK.
# Decoded sentence: আমি ঠিক আছি.
#
# -
# Input sentence: Listen.
# Decoded sentence: শুনুন।
#
# -
# Input sentence: No way!
# Decoded sentence: কোনভাবেই না!
#
# -
# Input sentence: No way!
# Decoded sentence: কোনভাবেই না!
#
# -
# Input sentence: No way!
# Decoded sentence: কোনভাবেই না!
#
# -
# Input sentence: No way!
# Decoded sentence: কোনভাবেই না!
#
# -
# Input sentence: No way!
# Decoded sentence: কোনভাবেই না!
#
# -
# Input sentence: No way!
# Decoded sentence: কোনভাবেই না!
#
# -
# Input sentence: No way!
# Decoded sentence: কোনভাবেই না!
#
# -
# Input sentence: No way!
# Decoded sentence: কোনভাবেই না!
#
# -
# Input sentence: No way!
# Decoded sentence: কোনভাবেই না!
#
# -
# Input sentence: Really?
# Decoded sentence: সত্যি?
#
# -
# Input sentence: Really?
# Decoded sentence: সত্যি?
#
# -
# Input sentence: Really?
# Decoded sentence: সত্যি?
#
# -
# Input sentence: Thanks.
# Decoded sentence: ধন্যবাদ।
#
# -
# Input sentence: We try.
# Decoded sentence: আমরা চেষ্টাকরি.
#
# -
# Input sentence: We won.
# Decoded sentence: আমরা জানি.
#
# -
# Input sentence: We won.
# Decoded sentence: আমরা জানি.
#
# -
# Input sentence: We won.
# Decoded sentence: আমরা জানি.
#
# -
# Input sentence: We won.
# Decoded sentence: আমরা জানি.
#
# -
# Input sentence: Ask Tom.
# Decoded sentence: টম জিজ্ঞাসা করুন।
#
# -
# Input sentence: Awesome!
# Decoded sentence: অসাধারণ!
#
# -
# Input sentence: Be calm.
# Decoded sentence: শান্ত হও.
#
# -
# Input sentence: Be calm.
# Decoded sentence: শান্ত হও.
#
# -
# Input sentence: Be calm.
# Decoded sentence: শান্ত হও.
#
# -
# Input sentence: Be cool.
# Decoded sentence: শান্ত হও.
#
# -
# Input sentence: Be fair.
# Decoded sentence: পরিষ্কার করা.
#
# -
# Input sentence: Be fair.
# Decoded sentence: পরিষ্কার করা.
#
# -
# Input sentence: Be fair.
# Decoded sentence: পরিষ্কার করা.
#
# -
# Input sentence: Be fair.
# Decoded sentence: পরিষ্কার করা.
#
# -
# Input sentence: Be fair.
# Decoded sentence: পরিষ্কার করা.
#
# -
# Input sentence: Be fair.
# Decoded sentence: পরিষ্কার করা.
#
# -
# Input sentence: Be kind.
# Decoded sentence: পয়াশ্লাহততেয়ে.
#
# -
# Input sentence: Be nice.
# Decoded sentence: সুন্দর হতে।
#
# -
# Input sentence: Be nice.
# Decoded sentence: সুন্দর হতে।
#
# -
# Input sentence: Be nice.
# Decoded sentence: সুন্দর হতে।
#
# -
# Input sentence: Be nice.
# Decoded sentence: সুন্দর হতে।
#
# -
# Input sentence: Be nice.
# Decoded sentence: সুন্দর হতে।
#
# -
# Input sentence: Be nice.
# Decoded sentence: সুন্দর হতে।
#
# -
# Input sentence: Beat it.
# Decoded sentence: এটা বীট।
#
# -
# Input sentence: Call me.
# Decoded sentence: আমাকে ডাকো.
#
# -
# Input sentence: Call me.
# Decoded sentence: আমাকে ডাকো.
#
# -
# Input sentence: Call us.
# Decoded sentence: আমাদের কল করুন।
#
# -
# Input sentence: Call us.
# Decoded sentence: আমাদের কল করুন।
#
# -
# Input sentence: Come in.
# Decoded sentence: ভিতরে আসো.
#
# -
# Input sentence: Come in.
# Decoded sentence: ভিতরে আসো.
#
# -
# Input sentence: Come in.
# Decoded sentence: ভিতরে আসো.
#
# -
# Input sentence: Come in.
# Decoded sentence: ভিতরে আসো.
#
# -
# Input sentence: Come on!
# Decoded sentence: চলে আসো!
#
# -
# Input sentence: Come on.
# Decoded sentence: চলে আসো.
